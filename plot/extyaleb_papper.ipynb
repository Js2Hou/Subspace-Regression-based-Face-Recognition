# %%
import numpy as np
import matplotlib.pyplot as plt

from data_loader import *
from utils import *

# %%
train_x, test_x, train_y, test_y = Dataloader.load_ExtYaleB_cropped2(test_size=0.3)

img0 = test_x[0].reshape(20,20).T
print(img0.shape)
plt.imshow(img0, cmap='gray')
# Out:
# (20, 20)

# %%
print(f'image\'s maximum is: {np.max(img0)}')
print(f'image\'s minimum is: {np.min(img0)}')
# Out:
# image's maximum is: 0.6129411764705883
# image's minimum is: 0.008627450980392169

# %%
snrs = [1, 0.8, 0.6, 0.4, 0.2]
plt.figure()
for id, snr in enumerate(snrs):
    img = addsalt_pepper(img0, snr)
    plt.subplot(1, 5, id + 1)
    plt.imshow(img, cmap='gray')
    plt.title(f'{snr}')
    plt.axis('off')
plt.savefig(f'./tem.jpg')
plt.show()
